# %%
import pandas as pd

# %%
flow=pd.read_csv('./flow_betw_country.csv',index_col=0)

# %%
country=flow['ques_owner_country'].to_list()

# %%
diff={}

# %%
country
# Out:
# ['USA',
#  'IND',
#  'GBR',
#  'DEU',
#  'CAN',
#  'FRA',
#  'AUS',
#  'PAK',
#  'NLD',
#  'BRA',
#  'RUS',
#  'ESP',
#  'POL',
#  'ITA',
#  'PHL',
#  'ISR',
#  'IRN',
#  'IDN',
#  'UKR',
#  'BGD',
#  'CHN',
#  'CHE',
#  'LKA',
#  'SWE',
#  'BEL',
#  'TUR',
#  'MYS',
#  'AUT',
#  'ZAF',
#  'IRL',
#  'DNK',
#  'ROU',
#  'PRT',
#  'MEX',
#  'NZL',
#  'CZE',
#  'NPL',
#  'VNM',
#  'ARG',
#  'EGY',
#  'JPN',
#  'GRC',
#  'NOR',
#  'KOR',
#  'ARE',
#  'COL',
#  'NGA',
#  'HUN',
#  'BGR',
#  'FIN',
#  'SRB',
#  'BLR',
#  'CHL',
#  'TWN',
#  'THA',
#  'KEN',
#  'TUN',
#  'SVK',
#  'LTU',
#  'MAR',
#  'HRV',
#  'URY',
#  'SVN',
#  'SAU',
#  'LBN',
#  'SOM',
#  'SOM',
#  'PER',
#  'GEO',
#  'EST',
#  'VEN',
#  'MMR',
#  'KAZ',
#  'DZA',
#  'LVA',
#  'BIH',
#  'GHA',
#  'JOR',
#  'ARM',
#  'ISL',
#  'KHM',
#  'CRI',
#  'AZE',
#  'UZB',
#  'CYP',
#  'CYP',
#  'MKD',
#  'LUX',
#  'CUB',
#  'AFG',
#  'DOM',
#  'ECU',
#  'MDA',
#  'TZA',
#  'IRQ',
#  'ALB',
#  'JAM',
#  'UGA',
#  'KWT',
#  'SLV',
# ...

# %%
round?

# %%
for i in country:
    diff[i]={}
    for j in country:
        expor=flow[(flow['ans_owner_country']==i)&(flow['ques_owner_country']==j)]['count'].iloc[0]
        impor=flow[(flow['ans_owner_country']==j)&(flow['ques_owner_country']==i)]['count'].iloc[0]
        diff[i][j]=round((int(expor)-int(impor))/int(expor),3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-22bdd58efc65> in <module>
#       3     for j in country:
#       4         expor=flow[(flow['ans_owner_country']==i)&(flow['ques_owner_country']==j)]['count'].iloc[0]
# ----> 5         impor=flow[(flow['ans_owner_country']==j)&(flow['ques_owner_country']==i)]['count'].iloc[0]
#       6         diff[i][j]=round((int(expor)-int(impor))/int(expor),3)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2155
# ...

# %%
diff
# Out:
# {'USA': {'USA': 0.0,
#   'IND': 0.256,
#   'GBR': 0.122,
#   'DEU': -0.305,
#   'CAN': 0.155,
#   'FRA': -0.108,
#   'AUS': -0.352,
#   'PAK': 0.47,
#   'NLD': -0.072,
#   'BRA': 0.365,
#   'RUS': -0.262,
#   'ESP': 0.188,
#   'POL': -0.175,
#   'ITA': 0.257,
#   'PHL': 0.499,
#   'ISR': -0.033,
#   'IRN': 0.318,
#   'IDN': 0.566,
#   'UKR': -0.028,
#   'BGD': -0.116,
#   'CHN': 0.192,
#   'CHE': -0.132,
#   'LKA': 0.134,
#   'SWE': 0.183,
#   'BEL': -0.04,
#   'TUR': 0.3,
#   'MYS': 0.466,
#   'AUT': -0.529,
#   'ZAF': 0.523,
#   'IRL': 0.209,
#   'DNK': 0.149,
#   'ROU': 0.23,
#   'PRT': 0.532,
#   'MEX': 0.348,
#   'NZL': -0.216,
#   'CZE': -0.26,
#   'NPL': 0.236,
#   'VNM': -0.018,
#   'ARG': 0.183,
#   'EGY': 0.478,
#   'JPN': -0.199,
#   'GRC': 0.138,
#   'NOR': -0.026,
#   'KOR': 0.454,
#   'ARE': 0.318,
#   'COL': 0.284,
#   'NGA': 0.336,
#   'HUN': -0.015,
#   'BGR': -0.085,
#   'FIN': -0.739,
#   'SRB': 0.189,
#   'BLR': -0.053,
#   'CHL': 0.462,
#   'TWN': 0.343,
# ...

# %% [markdown]
# ### fix France coordiantes

# %%
centroids=pd.read_csv('./centroids.csv',index_col=0)

# %%
centroids[centroids['name']=='France']
# Out:
#       name                                      centroid      long        lat  \
#
# 43  France  POINT (-2.876696699270627 42.46070432663372)  6.349014  50.864716
#
#    iso3
#
# 43  FRA

# %%
centroids[centroids['name']=='Spain']
# Out:
#       name                                      centroid      long        lat  \
#
# 132  Spain  POINT (-3.617020602387374 40.34865610622673) -3.617021  40.348656
#
#     iso3
#
# 132  ESP

# %%
centroids[centroids['name']=='Germany']
# Out:
#         name                                     centroid       long  \
#
# 121  Germany  POINT (10.28848509274285 51.13372269040778)  10.288485
#
#            lat iso3
#
# 121  51.133723  DEU

# %%
dir(centroids.loc[centroids['name']=='Spain',['centroid']])
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
centroids.loc[centroids['name']=='Spain',['centroid']].iloc[0,0]
# Out:
# 'POINT (-3.617020602387374 40.34865610622673)'
